# %% [markdown]
# # Colab Notebook for AI-ML-PROJECTS
#
# This is a starter Google Colab notebook. Update it with your project's code, datasets, and experiments.

# %%
# Example: imports and check GPU
import sys
import torch
print('Python:', sys.version)
print('PyTorch:', torch.__version__)
# !nvidia-smi
